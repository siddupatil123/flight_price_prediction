# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_excel("flight_price.xlsx")

# %%
df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Date_of_Journey  10683 non-null  object
#  2   Source           10683 non-null  object
#  3   Destination      10683 non-null  object
#  4   Route            10682 non-null  object
#  5   Dep_Time         10683 non-null  object
#  6   Arrival_Time     10683 non-null  object
#  7   Duration         10683 non-null  object
#  8   Total_Stops      10682 non-null  object
#  9   Additional_Info  10683 non-null  object
#  10  Price            10683 non-null  int64
# dtypes: int64(1), object(10)
# memory usage: 918.2+ KB

# %%
df.describe()
# Out:
#               Price
# count  10683.000000
# mean    9087.064121
# std     4611.359167
# min     1759.000000
# 25%     5277.000000
# 50%     8372.000000
# 75%    12373.000000
# max    79512.000000

# %%
df.isnull().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              1
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        1
# Additional_Info    0
# Price              0
# dtype: int64

# %%
#tfrom this we cxan find the null values present in route and total_stops

# %%
df['Route'].isnull().sum()
# Out:
# 1

# %%
df.dtypes
# Out:
# Airline            object
# Date_of_Journey    object
# Source             object
# Destination        object
# Route              object
# Dep_Time           object
# Arrival_Time       object
# Duration           object
# Total_Stops        object
# Additional_Info    object
# Price               int64
# dtype: object

# %%
##feature engginering

# %%
df['date']=df['Date_of_Journey'].str.split('/').str[0]
df['month']=df['Date_of_Journey'].str.split('/').str[1]
df['year']=df['Date_of_Journey'].str.split('/').str[2]

# %%
df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price date  \
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897   24
# 1    05:50         13:15   7h 25m     2 stops         No info   7662    1
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882    9
# 3    18:05         23:30   5h 25m      1 stop         No info   6218   12
# 4    16:50         21:35   4h 45m      1 stop         No info  13302   01
#
#   month  year
# 0    03  2019
# 1    05  2019
# 2    06  2019
# ...

# %%
df.drop(labels='Date_of_Journey',axis=1,inplace=True)

# %%
df.head()
# Out:
#    Total_Stops  Price  date  month  year  Dep_hour  Dep_minute Duration_hour  \
# 0            0   3897    24      3  2019        22          20             2
# 1            2   7662     1      5  2019         5          50             7
# 2            2  13882     9      6  2019         9          25            19
# 3            1   6218    12      5  2019        18           5             5
# 4            1  13302     1      3  2019        16          50             4
#
#   Duration_minute  Arrival_hour  ...  Destination_New Delhi  \
# 0              50             1  ...                      1
# 1              25            13  ...                      0
# 2             NaN             4  ...                      0
# 3              25            23  ...                      0
# 4              45            21  ...                      1
#
#    Additional_Info_1 Short layover  Additional_Info_2 Long layover  \
# 0                                0                               0
# ...

# %%
df['Dep_hour']=df['Dep_Time'].str.split(':').str[0]
df['Dep_minute']=df['Dep_Time'].str.split(':').str[1]

# %%
df.head()
# Out:
#        Airline    Source Destination                  Route Dep_Time  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
#
#    Arrival_Time Duration Total_Stops Additional_Info  Price date month  year  \
# 0  01:10 22 Mar   2h 50m    non-stop         No info   3897   24    03  2019
# 1         13:15   7h 25m     2 stops         No info   7662    1    05  2019
# 2  04:25 10 Jun      19h     2 stops         No info  13882    9    06  2019
# 3         23:30   5h 25m      1 stop         No info   6218   12    05  2019
# 4         21:35   4h 45m      1 stop         No info  13302   01    03  2019
#
#   Dep_hour Dep_minute
# 0       22         20
# 1       05         50
# ...

# %%
df.drop(labels='Dep_Time',axis=1,inplace=True)

# %%
df.head()
# Out:
#        Airline    Source Destination                  Route  Arrival_Time  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL  01:10 22 Mar
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR         13:15
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK  04:25 10 Jun
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR         23:30
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL         21:35
#
#   Duration Total_Stops Additional_Info  Price date month  year Dep_hour  \
# 0   2h 50m    non-stop         No info   3897   24    03  2019       22
# 1   7h 25m     2 stops         No info   7662    1    05  2019       05
# 2      19h     2 stops         No info  13882    9    06  2019       09
# 3   5h 25m      1 stop         No info   6218   12    05  2019       18
# 4   4h 45m      1 stop         No info  13302   01    03  2019       16
#
#   Dep_minute
# 0         20
# 1         50
# 2         25
# 3         05
# 4         50

# %%
df['Duration_hour']=df['Duration'].str.split(" ").str[0].str.replace("h","")
df['Duration_minute']=df['Duration'].str.split(" ").str[1].str.replace("m","")

# %%
df.head()
# Out:
#        Airline    Source Destination                  Route  Arrival_Time  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL  01:10 22 Mar
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR         13:15
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK  04:25 10 Jun
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR         23:30
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL         21:35
#
#   Duration Total_Stops Additional_Info  Price date month  year Dep_hour  \
# 0   2h 50m    non-stop         No info   3897   24    03  2019       22
# 1   7h 25m     2 stops         No info   7662    1    05  2019       05
# 2      19h     2 stops         No info  13882    9    06  2019       09
# 3   5h 25m      1 stop         No info   6218   12    05  2019       18
# 4   4h 45m      1 stop         No info  13302   01    03  2019       16
#
#   Dep_minute Duration_hour Duration_minute
# 0         20             2              50
# ...

# %%
df.drop(labels='Duration',axis=1,inplace=True)

# %%
df.head()
# Out:
#        Airline    Source Destination                  Route  Arrival_Time  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL  01:10 22 Mar
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR         13:15
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK  04:25 10 Jun
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR         23:30
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL         21:35
#
#   Total_Stops Additional_Info  Price date month  year Dep_hour Dep_minute  \
# 0    non-stop         No info   3897   24    03  2019       22         20
# 1     2 stops         No info   7662    1    05  2019       05         50
# 2     2 stops         No info  13882    9    06  2019       09         25
# 3      1 stop         No info   6218   12    05  2019       18         05
# 4      1 stop         No info  13302   01    03  2019       16         50
#
#   Duration_hour Duration_minute
# 0             2              50
# ...

# %%
df['Additional_Info'].unique()
# Out:
# array(['No info', 'In-flight meal not included',
#        'No check-in baggage included', '1 Short layover', 'No Info',
#        '1 Long layover', 'Change airports', 'Business class',
#        'Red-eye flight', '2 Long layover'], dtype=object)

# %%
df['date'].astype(int)
# Out:
# 0        24
# 1         1
# 2         9
# 3        12
# 4         1
#          ..
# 10678     9
# 10679    27
# 10680    27
# 10681     1
# 10682     9
# Name: date, Length: 10683, dtype: int32

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Source           10683 non-null  object
#  2   Destination      10683 non-null  object
#  3   Route            10682 non-null  object
#  4   Arrival_Time     10683 non-null  object
#  5   Total_Stops      10682 non-null  object
#  6   Additional_Info  10683 non-null  object
#  7   Price            10683 non-null  int64
#  8   date             10683 non-null  object
#  9   month            10683 non-null  object
#  10  year             10683 non-null  object
#  11  Dep_hour         10683 non-null  object
#  12  Dep_minute       10683 non-null  object
#  13  Duration_hour    10683 non-null  object
#  14  Duration_minute  9651 non-null   object
# dtypes: int64(1), object(14)
# memory usage: 1.2+ MB

# %%
df['date']=df['date'].astype(int)
df['month']=df['month'].astype(int)
df['year']=df['year'].astype(int)

# %%
df['Dep_hour']=df['Dep_hour'].astype(int)
df['Dep_minute']=df['Dep_minute'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Source           10683 non-null  object
#  2   Destination      10683 non-null  object
#  3   Route            10682 non-null  object
#  4   Total_Stops      10683 non-null  int64
#  5   Additional_Info  10683 non-null  object
#  6   Price            10683 non-null  int64
#  7   date             10683 non-null  int32
#  8   month            10683 non-null  int32
#  9   year             10683 non-null  int32
#  10  Dep_hour         10683 non-null  int32
#  11  Dep_minute       10683 non-null  int32
#  12  Duration_hour    10683 non-null  object
#  13  Duration_minute  9651 non-null   object
#  14  Arrival_hour     10683 non-null  int32
#  15  Arrival_minute   10683 non-null  int32
# dtypes: int32(7), int64(2), object(7)
# ...

# %%
df['Arrival_Time']=df['Arrival_Time'].str.split(' ').str[0]

# %%
df.head()
# Out:
#        Airline    Source Destination                  Route Arrival_Time  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL        01:10
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR        13:15
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK        04:25
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR        23:30
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL        21:35
#
#   Total_Stops Additional_Info  Price  date  month  year  Dep_hour  Dep_minute  \
# 0    non-stop         No info   3897    24      3  2019        22          20
# 1     2 stops         No info   7662     1      5  2019         5          50
# 2     2 stops         No info  13882     9      6  2019         9          25
# 3      1 stop         No info   6218    12      5  2019        18           5
# 4      1 stop         No info  13302     1      3  2019        16          50
#
#   Duration_hour Duration_minute
# ...

# %%
df[df["Total_Stops"].isnull()]
# Out:
# Empty DataFrame
# Columns: [Airline, Source, Destination, Route, Arrival_Time, Total_Stops, Additional_Info, Price, date, month, year, Dep_hour, Dep_minute, Duration_hour, Duration_minute]
# Index: []

# %%
df['Total_Stops']=df["Total_Stops"].fillna('1 stop')

# %%
df["Total_Stops"].unique()
# Out:
# array(['non-stop', '2 stops', '1 stop', '3 stops', '4 stops'],
#       dtype=object)

# %%
df["Total_Stops"]=df["Total_Stops"].map({'non-stop':0,'1 stop':1,'2 stops':2,'3 stops':3, '4 stops':4})

# %%
df.head()
# Out:
#        Airline    Source Destination                  Route Arrival_Time  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL        01:10
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR        13:15
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK        04:25
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR        23:30
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL        21:35
#
#    Total_Stops Additional_Info  Price  date  month  year  Dep_hour  \
# 0            0         No info   3897    24      3  2019        22
# 1            2         No info   7662     1      5  2019         5
# 2            2         No info  13882     9      6  2019         9
# 3            1         No info   6218    12      5  2019        18
# 4            1         No info  13302     1      3  2019        16
#
#    Dep_minute Duration_hour Duration_minute
# 0          20             2              50
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Source           10683 non-null  object
#  2   Destination      10683 non-null  object
#  3   Route            10682 non-null  object
#  4   Arrival_Time     10683 non-null  object
#  5   Total_Stops      10683 non-null  int64
#  6   Additional_Info  10683 non-null  object
#  7   Price            10683 non-null  int64
#  8   date             10683 non-null  int32
#  9   month            10683 non-null  int32
#  10  year             10683 non-null  int32
#  11  Dep_hour         10683 non-null  int32
#  12  Dep_minute       10683 non-null  int32
#  13  Duration_hour    10683 non-null  object
#  14  Duration_minute  9651 non-null   object
# dtypes: int32(5), int64(2), object(8)
# memory usage: 1.0+ MB

# %%
df['Arrival_hour']=df['Arrival_Time'].str.split(':').str[0]
df['Arrival_minute']=df['Arrival_Time'].str.split(':').str[1]

# %%
df.head()
# Out:
#        Airline    Source Destination                  Route Arrival_Time  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL        01:10
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR        13:15
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK        04:25
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR        23:30
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL        21:35
#
#    Total_Stops Additional_Info  Price  date  month  year  Dep_hour  \
# 0            0         No info   3897    24      3  2019        22
# 1            2         No info   7662     1      5  2019         5
# 2            2         No info  13882     9      6  2019         9
# 3            1         No info   6218    12      5  2019        18
# 4            1         No info  13302     1      3  2019        16
#
#    Dep_minute Duration_hour Duration_minute Arrival_hour Arrival_minute
# ...

# %%
df.drop(labels='Arrival_Time',inplace=True,axis=1)

# %%
df.head()
# Out:
#        Airline    Source Destination                  Route  Total_Stops  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL            0
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR            2
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK            2
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR            1
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL            1
#
#   Additional_Info  Price  date  month  year  Dep_hour  Dep_minute  \
# 0         No info   3897    24      3  2019        22          20
# 1         No info   7662     1      5  2019         5          50
# 2         No info  13882     9      6  2019         9          25
# 3         No info   6218    12      5  2019        18           5
# 4         No info  13302     1      3  2019        16          50
#
#   Duration_hour Duration_minute Arrival_hour Arrival_minute
# 0             2              50           01             10
# ...

# %%
df['Arrival_hour']=df['Arrival_hour'].astype(int)
df['Arrival_minute']=df['Arrival_minute'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Source           10683 non-null  object
#  2   Destination      10683 non-null  object
#  3   Route            10682 non-null  object
#  4   Total_Stops      10683 non-null  int64
#  5   Additional_Info  10683 non-null  object
#  6   Price            10683 non-null  int64
#  7   date             10683 non-null  int32
#  8   month            10683 non-null  int32
#  9   year             10683 non-null  int32
#  10  Dep_hour         10683 non-null  int32
#  11  Dep_minute       10683 non-null  int32
#  12  Duration_hour    10683 non-null  object
#  13  Duration_minute  9651 non-null   object
#  14  Arrival_hour     10683 non-null  int32
#  15  Arrival_minute   10683 non-null  int32
# dtypes: int32(7), int64(2), object(7)
# ...

# %%
df.head(2)
# Out:
#      Airline    Source Destination                  Route  Total_Stops  \
# 0     IndiGo  Banglore   New Delhi              BLR → DEL            0
# 1  Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR            2
#
#   Additional_Info  Price  date  month  year  Dep_hour  Dep_minute  \
# 0         No info   3897    24      3  2019        22          20
# 1         No info   7662     1      5  2019         5          50
#
#   Duration_hour Duration_minute  Arrival_hour  Arrival_minute
# 0             2              50             1              10
# 1             7              25            13              15

# %%
df['Airline'].unique()
# Out:
# array(['IndiGo', 'Air India', 'Jet Airways', 'SpiceJet',
#        'Multiple carriers', 'GoAir', 'Vistara', 'Air Asia',
#        'Vistara Premium economy', 'Jet Airways Business',
#        'Multiple carriers Premium economy', 'Trujet'], dtype=object)

# %%
df['Source'].unique()
# Out:
# array(['Banglore', 'Kolkata', 'Delhi', 'Chennai', 'Mumbai'], dtype=object)

# %%
df['Additional_Info'].unique()
# Out:
# array(['No info', 'In-flight meal not included',
#        'No check-in baggage included', '1 Short layover', 'No Info',
#        '1 Long layover', 'Change airports', 'Business class',
#        'Red-eye flight', '2 Long layover'], dtype=object)

# %%
df=pd.get_dummies(df,columns=['Airline','Source','Destination','Additional_Info'],drop_first=True)

# %%
df.isnull().sum()
# Out:
# Airline               0
# Source                0
# Destination           0
# Route                 1
# Total_Stops           0
# Additional_Info       0
# Price                 0
# date                  0
# month                 0
# year                  0
# Dep_hour              0
# Dep_minute            0
# Duration_hour         0
# Duration_minute    1032
# Arrival_hour          0
# Arrival_minute        0
# Route_1               1
# dtype: int64

# %%
df.drop(labels=['Duration_minute','Duration_hour'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    Total_Stops  Price  date  month  year  Dep_hour  Dep_minute  Arrival_hour  \
# 0            0   3897    24      3  2019        22          20             1
# 1            2   7662     1      5  2019         5          50            13
# 2            2  13882     9      6  2019         9          25             4
# 3            1   6218    12      5  2019        18           5            23
# 4            1  13302     1      3  2019        16          50            21
#
#    Arrival_minute  Airline_Air India  ...  Destination_New Delhi  \
# 0              10                  0  ...                      1
# 1              15                  1  ...                      0
# 2              25                  0  ...                      0
# 3              30                  0  ...                      0
# 4              35                  0  ...                      1
#
#    Additional_Info_1 Short layover  Additional_Info_2 Long layover  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 40 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Total_Stops                                   10683 non-null  int64
#  1   Price                                         10683 non-null  int64
#  2   date                                          10683 non-null  int32
#  3   month                                         10683 non-null  int32
#  4   year                                          10683 non-null  int32
#  5   Dep_hour                                      10683 non-null  int32
#  6   Dep_minute                                    10683 non-null  int32
#  7   Duration_hour                                 10683 non-null  object
#  8   Duration_minute                               9651 non-null   object
# ...

# %%
df.head()
# Out:
#    Total_Stops  Price  date  month  year  Dep_hour  Dep_minute  Arrival_hour  \
# 0            0   3897    24      3  2019        22          20             1
# 1            2   7662     1      5  2019         5          50            13
# 2            2  13882     9      6  2019         9          25             4
# 3            1   6218    12      5  2019        18           5            23
# 4            1  13302     1      3  2019        16          50            21
#
#    Arrival_minute  Airline_Air India  ...  Destination_New Delhi  \
# 0              10                  0  ...                      1
# 1              15                  1  ...                      0
# 2              25                  0  ...                      0
# 3              30                  0  ...                      0
# 4              35                  0  ...                      1
#
#    Additional_Info_1 Short layover  Additional_Info_2 Long layover  \
# ...

# %%
##Model traing

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
X_train=df.drop(['Price'],axis=1)

# %%
## Capture the dependent feature
y_train=df[['Price']]

# %%
x_train,x_test,y_train,y_test=train_test_split(X_train,y_train)

# %%
x_train.head()
# Out:
#       Total_Stops  date  month  year  Dep_hour  Dep_minute  Arrival_hour  \
# 3040            1    12      6  2019         9           0            19
# 3427            1     6      5  2019         6          30             9
# 760             1     3      3  2019         4          45            11
# 5654            0    12      6  2019        19          50            22
# 6777            1    15      3  2019        13          50            22
#
#       Arrival_minute  Airline_Air India  Airline_GoAir  ...  \
# 3040               0                  0              0  ...
# 3427              20                  0              0  ...
# 760               30                  0              0  ...
# 5654              50                  0              0  ...
# 6777              10                  1              0  ...
#
#       Destination_New Delhi  Additional_Info_1 Short layover  \
# 3040                      0                                0
# ...

# %%
y_train
# Out:
#        Price
# 3040   10262
# 3427    9663
# 760    14871
# 5654    5769
# 6777    9166
# ...      ...
# 5174    6205
# 6179    5999
# 224    13014
# 4751   17471
# 10217   4804
#
# [8012 rows x 1 columns]

# %%
reg=LinearRegression()
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=reg.predict(x_test)

# %%
score=reg.score(x_test,y_test)
score
# Out:
# 0.7132473083456723
